# %%
from pathlib import Path

# Folder of data
DATA_DIR = Path("data")

# Review Files
REVIEWS_FILE = DATA_DIR / "Beauty_and_Personal_Care.jsonl.gz"

#w
METADATA_FILE = DATA_DIR / "meta_Beauty_and_Personal_Care.jsonl.gz"

print("Reviews:", REVIEWS_FILE)
print("Metadata:", METADATA_FILE)
# Out:
# Reviews: data/Beauty_and_Personal_Care.jsonl.gz
# Metadata: data/meta_Beauty_and_Personal_Care.jsonl.gz

# %% [markdown]
# # Sección nueva

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # AMAZON REVIEWS
